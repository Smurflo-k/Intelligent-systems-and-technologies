# %%
import pandas as pd

# %%
df = pd.read_excel("data.xlsx")
df
# Out:
#     Ваш пол  Возраст    Характер Что вы предпочитаете?  \
# 0   Женский       22     Холерик                  Кофе
# 1   Мужской       22     Холерик                   Чай
# 2   Мужской       22  Меланхолик                  Кофе
# 3   Мужской       22   Флегматик                   Чай
# 4   Мужской       21   Флегматик                   Чай
# 5   Мужской       22   Флегматик                  Кофе
# 6   Мужской       21   Флегматик                   Чай
# 7   Женский       21  Меланхолик                   Чай
# 8   Мужской       22  Меланхолик                  Кофе
# 9   Мужской       22     Холерик                  Кофе
# 10  Мужской       22  Меланхолик                   Чай
# 11  Мужской       21   Флегматик                   Чай
# 12  Мужской       21   Сангвиник                  Кофе
# 13  Мужской       21   Сангвиник                  Кофе
# 14  Мужской       21     Холерик                  Кофе
# 15  Мужской       21     Холерик                   Чай
# 16  Мужской       21   Сангвиник                  Кофе
# 17  Мужской       21   Флегматик                  Кофе
# 18  Мужской       22  Меланхолик                   Чай
# 19  Мужской       22   Флегматик                   Чай
# 20  Мужской       21   Флегматик                   Чай
# 21  Мужской       22   Флегматик                   Чай
# 22  Мужской       22   Флегматик                  Кофе
# 23  Мужской       21     Холерик                   Чай
# 24  Мужской       22   Сангвиник                   Чай
# 25  Женский       21   Сангвиник                  Кофе
# 26  Мужской       21   Флегматик                   Чай
# 27  Мужской       21  Меланхолик                  Кофе
# 28  Женский       24  Меланхолик                   Чай
# 29  Мужской       22   Сангвиник                   Чай
# 30  Мужской       22   Флегматик                   Чай
# 31  Женский       22   Сангвиник                   Чай
# 32  Женский       21     Холерик                   Чай
# 33  Мужской       21     Холерик                  Кофе
# 34  Мужской       22  Меланхолик                  Кофе
# 35  Мужской       21   Сангвиник                   Чай
# 36  Мужской       21  Меланхолик                  Кофе
# 37  Мужской       22  Меланхолик                   Чай
#
#    Как часто вы берете инициативу в свои руки?  \
# 0                                 Периодически
# 1                                        Часто
# 2                                  Очень редко
# 3                                        Часто
# 4                                        Часто
# 5                                 Периодически
# 6                                        Редко
# 7                                 Периодически
# 8                                 Периодически
# 9                                        Часто
# 10                                       Редко
# 11                                       Часто
# 12                                Периодически
# 13                                       Редко
# 14                                       Часто
# 15                                       Часто
# 16                                Периодически
# 17                                       Редко
# 18                                Периодически
# 19                                Периодически
# 20                                Периодически
# 21                                Периодически
# 22                                Периодически
# 23                                Периодически
# 24                                 Очень часто
# 25                                       Часто
# 26                                Периодически
# 27                                       Редко
# 28                                Периодически
# 29                                 Очень часто
# 30                                 Очень часто
# 31                                Периодически
# 32                                Периодически
# 33                                       Часто
# 34                                Периодически
# 35                                Периодически
# 36                                Периодически
# 37                                       Часто
#
#     Как часто вы берете инициативу в свои руки? / Баллы  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
#
#    Как часто вы пропускаете завтраки?  \
# 0                         Очень часто
# 1                         Очень часто
# 2                               Часто
# 3                         Очень редко
# 4                               Редко
# 5                         Очень часто
# 6                               Часто
# 7                               Редко
# 8                         Очень редко
# 9                        Периодически
# 10                        Очень редко
# 11                        Очень часто
# 12                              Часто
# 13                        Очень часто
# 14                        Очень редко
# 15                              Редко
# 16                       Периодически
# 17                              Часто
# 18                       Периодически
# 19                              Редко
# 20                        Очень редко
# 21                              Часто
# 22                              Часто
# 23                              Часто
# 24                        Очень редко
# 25                              Часто
# 26                        Очень редко
# 27                              Редко
# 28                              Редко
# 29                        Очень часто
# 30                        Очень редко
# 31                        Очень часто
# 32                        Очень редко
# 33                        Очень часто
# 34                              Часто
# 35                              Редко
# 36                        Очень редко
# 37                        Очень часто
#
#     Как часто вы пропускаете завтраки? / Баллы  Сколько спите ночью в среднем  \
# 0                                          NaN                             10
# 1                                          NaN                              6
# 2                                          NaN                              6
# 3                                          NaN                              6
# 4                                          NaN                              8
# 5                                          NaN                              5
# 6                                          NaN                              9
# 7                                          NaN                              7
# 8                                          NaN                              6
# 9                                          NaN                              7
# 10                                         NaN                              7
# 11                                         NaN                              7
# 12                                         NaN                              5
# 13                                         NaN                              9
# 14                                         NaN                              7
# 15                                         NaN                              7
# 16                                         NaN                              6
# 17                                         NaN                              8
# 18                                         NaN                              6
# 19                                         NaN                              6
# 20                                         NaN                              8
# 21                                         NaN                              8
# 22                                         NaN                              6
# 23                                         NaN                              7
# 24                                         NaN                             10
# 25                                         NaN                              6
# 26                                         NaN                              7
# 27                                         NaN                              9
# 28                                         NaN                              7
# 29                                         NaN                              8
# 30                                         NaN                              6
# 31                                         NaN                              7
# 32                                         NaN                              7
# 33                                         NaN                              5
# 34                                         NaN                              6
# 35                                         NaN                              8
# 36                                         NaN                             10
# 37                                         NaN                              7
#
#    Гипертония  ... Любимое время года? Любимое время года? / Баллы  \
# 0         Нет  ...               Весна                         NaN
# 1          Да  ...               Весна                         NaN
# 2         Нет  ...               Весна                         NaN
# 3         Нет  ...                Лето                         NaN
# 4         Нет  ...               Осень                         NaN
# 5         Нет  ...               Весна                         NaN
# 6         Нет  ...               Весна                         NaN
# 7         Нет  ...                Зима                         NaN
# 8         Нет  ...                Зима                         NaN
# 9          Да  ...                Лето                         NaN
# 10        Нет  ...               Осень                         NaN
# 11         Да  ...                Зима                         NaN
# 12         Да  ...                Зима                         NaN
# 13        Нет  ...                Зима                         NaN
# 14        Нет  ...                Лето                         NaN
# 15        Нет  ...                Лето                         NaN
# 16        Нет  ...               Осень                         NaN
# 17        Нет  ...                Зима                         NaN
# 18        Нет  ...                Зима                         NaN
# 19        Нет  ...               Осень                         NaN
# 20        Нет  ...                Лето                         NaN
# 21        Нет  ...               Весна                         NaN
# 22        Нет  ...                Лето                         NaN
# 23        Нет  ...               Весна                         NaN
# 24        Нет  ...                Зима                         NaN
# 25        Нет  ...               Осень                         NaN
# 26        Нет  ...                Лето                         NaN
# 27        Нет  ...               Весна                         NaN
# 28        Нет  ...                Лето                         NaN
# 29        Нет  ...                Лето                         NaN
# 30        Нет  ...                Лето                         NaN
# 31        Нет  ...               Весна                         NaN
# 32        Нет  ...               Весна                         NaN
# 33        Нет  ...                Лето                         NaN
# 34        Нет  ...               Весна                         NaN
# 35        Нет  ...               Весна                         NaN
# 36        Нет  ...                Зима                         NaN
# 37        Нет  ...                Лето                         NaN
#
#    Что пьют родители Что пьют родители / Баллы Какие напитки любите  \
# 0         Чай и кофе                       NaN             Холодные
# 1                Чай                       NaN             Холодные
# 2               Кофе                       NaN             Холодные
# 3         Чай и кофе                       NaN             Холодные
# 4         Чай и кофе                       NaN              Горячие
# 5         Чай и кофе                       NaN             Холодные
# 6         Чай и кофе                       NaN              Горячие
# 7               Кофе                       NaN              Горячие
# 8         Чай и кофе                       NaN             Холодные
# 9         Чай и кофе                       NaN              Горячие
# 10               Чай                       NaN              Горячие
# 11        Чай и кофе                       NaN             Холодные
# 12        Чай и кофе                       NaN              Горячие
# 13        Чай и кофе                       NaN             Холодные
# 14              Кофе                       NaN              Горячие
# 15        Чай и кофе                       NaN             Холодные
# 16        Чай и кофе                       NaN              Горячие
# 17        Чай и кофе                       NaN             Холодные
# 18              Кофе                       NaN              Горячие
# 19        Чай и кофе                       NaN             Холодные
# 20        Чай и кофе                       NaN             Холодные
# 21        Чай и кофе                       NaN              Горячие
# 22        Чай и кофе                       NaN             Холодные
# 23        Чай и кофе                       NaN             Холодные
# 24        Чай и кофе                       NaN              Горячие
# 25        Чай и кофе                       NaN             Холодные
# 26        Чай и кофе                       NaN             Холодные
# 27               Чай                       NaN             Холодные
# 28        Чай и кофе                       NaN              Горячие
# 29               Чай                       NaN             Холодные
# 30               Чай                       NaN              Горячие
# 31               Чай                       NaN             Холодные
# 32               Чай                       NaN              Горячие
# 33        Чай и кофе                       NaN              Горячие
# 34        Чай и кофе                       NaN             Холодные
# 35              Кофе                       NaN             Холодные
# 36        Чай и кофе                       NaN              Горячие
# 37        Чай и кофе                       NaN              Горячие
#
#    Какие напитки любите / Баллы Азартен?  Набрано баллов Всего баллов  \
# 0                           NaN      Нет               0            0
# 1                           NaN       Да               0            0
# 2                           NaN      Нет               0            0
# 3                           NaN      Нет               0            0
# 4                           NaN      Нет               0            0
# 5                           NaN      Нет               0            0
# 6                           NaN      Нет               0            0
# 7                           NaN      Нет               0            0
# 8                           NaN       Да               0            0
# 9                           NaN      Нет               0            0
# 10                          NaN      Нет               0            0
# 11                          NaN       Да               0            0
# 12                          NaN      Нет               0            0
# 13                          NaN      Нет               0            0
# 14                          NaN      Нет               0            0
# 15                          NaN      Нет               0            0
# 16                          NaN      Нет               0            0
# 17                          NaN      Нет               0            0
# 18                          NaN      Нет               0            0
# 19                          NaN       Да               0            0
# 20                          NaN       Да               0            0
# 21                          NaN      Нет               0            0
# 22                          NaN      Нет               0            0
# 23                          NaN       Да               0            0
# 24                          NaN      Нет               0            0
# 25                          NaN      Нет               0            0
# 26                          NaN      Нет               0            0
# 27                          NaN       Да               0            0
# 28                          NaN      Нет               0            0
# 29                          NaN      Нет               0            0
# 30                          NaN      Нет               0            0
# 31                          NaN      Нет               0            0
# 32                          NaN       Да               0            0
# 33                          NaN      Нет               0            0
# 34                          NaN      Нет               0            0
# 35                          NaN      Нет               0            0
# 36                          NaN      Нет               0            0
# 37                          NaN       Да               0            0
#
#    Результат теста
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# 30             NaN
# 31             NaN
# 32             NaN
# 33             NaN
# 34             NaN
# 35             NaN
# 36             NaN
# 37             NaN
#
# [38 rows x 36 columns]

# %%
df.columns.tolist()
# Out:
# ['Ваш пол',
#  'Возраст',
#  'Характер',
#  'Что вы предпочитаете?',
#  'Как часто вы берете инициативу в свои руки?',
#  'Как часто вы берете инициативу в свои руки? / Баллы',
#  'Как часто вы пропускаете завтраки?',
#  'Как часто вы пропускаете завтраки? / Баллы',
#  'Сколько спите ночью в среднем',
#  'Гипертония',
#  'Курите?',
#  'Пьете энергетики?',
#  'Бывают ли проблемы со сном?',
#  'Повышенная тревожность?',
#  'Проблемы с концентрацией',
#  'Наличие кофейни возле дома',
#  'Какая культура ближе',
#  'Какая культура ближе / Баллы',
#  'Любишь ли горькое',
#  'Занимаетесь спортом?',
#  'Выпиваете алкоголь',
#  'Выпиваете алкоголь / Баллы',
#  'Время подъема',
#  'Формат работы',
#  'Формат работы / Баллы',
#  'Любите сладкое?',
#  'Любимое время года?',
#  'Любимое время года? / Баллы',
#  'Что пьют родители',
#  'Что пьют родители / Баллы',
#  'Какие напитки любите',
#  'Какие напитки любите / Баллы',
#  'Азартен?',
#  'Набрано баллов',
#  'Всего баллов',
#  'Результат теста']

# %%
bad_columns = [
    'Как часто вы берете инициативу в свои руки? / Баллы',
    'Как часто вы пропускаете завтраки? / Баллы',
    'Какая культура ближе / Баллы',
    'Выпиваете алкоголь / Баллы',
    'Формат работы / Баллы',
    'Любимое время года? / Баллы',
    'Что пьют родители / Баллы',
    'Какие напитки любите / Баллы',
    'Набрано баллов',
    'Всего баллов',
    'Результат теста',
]
df = df.drop(columns=bad_columns)

# %%
df.to_csv("data.csv", mode="w+", index=False)

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#    Ваш пол  Возраст    Характер Что вы предпочитаете?  \
# 0  Женский       22     Холерик                  Кофе
# 1  Мужской       22     Холерик                   Чай
# 2  Мужской       22  Меланхолик                  Кофе
# 3  Мужской       22   Флегматик                   Чай
# 4  Мужской       21   Флегматик                   Чай
#
#   Как часто вы берете инициативу в свои руки?  \
# 0                                Периодически
# 1                                       Часто
# 2                                 Очень редко
# 3                                       Часто
# 4                                       Часто
#
#   Как часто вы пропускаете завтраки?  Сколько спите ночью в среднем  \
# 0                        Очень часто                             10
# 1                        Очень часто                              6
# 2                              Часто                              6
# 3                        Очень редко                              6
# 4                              Редко                              8
#
#   Гипертония Курите? Пьете энергетики?  ... Любишь ли горькое  \
# 0        Нет      Да                Да  ...               Нет
# 1         Да     Нет               Нет  ...               Нет
# 2        Нет      Да                Да  ...               Нет
# 3        Нет      Да               Нет  ...               Нет
# 4        Нет     Нет               Нет  ...               Нет
#
#   Занимаетесь спортом? Выпиваете алкоголь Время подъема Формат работы  \
# 0                  Нет              Редко            12    Не работаю
# 1                  Нет                Нет             6      Удаленка
# 2                  Нет                 Да             7          Офис
# 3                  Нет                Нет            12          Офис
# 4                   Да                Нет             8      Удаленка
#
#   Любите сладкое? Любимое время года? Что пьют родители  Какие напитки любите  \
# 0              Да               Весна        Чай и кофе              Холодные
# 1             Нет               Весна               Чай              Холодные
# 2             Нет               Весна              Кофе              Холодные
# 3              Да                Лето        Чай и кофе              Холодные
# 4              Да               Осень        Чай и кофе               Горячие
#
#   Азартен?
# 0      Нет
# 1       Да
# 2      Нет
# 3      Нет
# 4      Нет
#
# [5 rows x 25 columns]

# %%
numeric_cols = ['Возраст', 'Сколько спите ночью в среднем', 'Время подъема']
categorical_cols = [col for col in df.columns if col not in numeric_cols]
data_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
print(data_encoded.columns)

for col in numeric_cols:
    data_encoded[col] = (data_encoded[col] - data_encoded[col].min()) / (
            data_encoded[col].max() - data_encoded[col].min())
# data_encoded = pd.get_dummies(data, drop_first=True)
print("Total number of rows in dataset = {}".format(data_encoded.shape[0]))
print("Total number of columns in dataset = {}".format(data_encoded.shape[1]))
data_encoded.head()
# Out:
# Index(['Возраст', 'Сколько спите ночью в среднем', 'Время подъема',
#        'Ваш пол_Мужской', 'Характер_Сангвиник', 'Характер_Флегматик',
#        'Характер_Холерик', 'Что вы предпочитаете?_Чай',
#        'Как часто вы берете инициативу в свои руки?_Очень часто',
#        'Как часто вы берете инициативу в свои руки?_Периодически',
#        'Как часто вы берете инициативу в свои руки?_Редко',
#        'Как часто вы берете инициативу в свои руки?_Часто',
#        'Как часто вы пропускаете завтраки?_Очень часто',
#        'Как часто вы пропускаете завтраки?_Периодически',
#        'Как часто вы пропускаете завтраки?_Редко',
#        'Как часто вы пропускаете завтраки?_Часто', 'Гипертония_Нет',
#        'Курите?_Нет', 'Пьете энергетики?_Нет',
#        'Бывают ли проблемы со сном?_Нет', 'Повышенная тревожность?_Нет',
#        'Проблемы с концентрацией_Нет', 'Наличие кофейни возле дома_Нет',
#        'Какая культура ближе_Запад', 'Какая культура ближе_Не знаю',
#        'Любишь ли горькое_Нет', 'Занимаетесь спортом?_Нет',
#        'Выпиваете алкоголь_Нет', 'Выпиваете алкоголь_Редко',
#        'Формат работы_Не работаю', 'Формат работы_Офис',
#        'Формат работы_Посменно', 'Формат работы_Удаленка',
#        'Любите сладкое?_Нет', 'Любимое время года?_Зима',
#        'Любимое время года?_Лето', 'Любимое время года?_Осень',
#        'Что пьют родители_Чай', 'Что пьют родители_Чай и кофе',
#        'Какие напитки любите_Холодные', 'Азартен?_Нет'],
#       dtype='object')
# Total number of rows in dataset = 38
# Total number of columns in dataset = 41
#     Возраст  Сколько спите ночью в среднем  Время подъема  Ваш пол_Мужской  \
# 0  0.333333                            1.0            0.8            False
# 1  0.333333                            0.2            0.2             True
# 2  0.333333                            0.2            0.3             True
# 3  0.333333                            0.2            0.8             True
# 4  0.000000                            0.6            0.4             True
#
#    Характер_Сангвиник  Характер_Флегматик  Характер_Холерик  \
# 0               False               False              True
# 1               False               False              True
# 2               False               False             False
# 3               False                True             False
# 4               False                True             False
#
#    Что вы предпочитаете?_Чай  \
# 0                      False
# 1                       True
# 2                      False
# 3                       True
# 4                       True
#
#    Как часто вы берете инициативу в свои руки?_Очень часто  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Как часто вы берете инициативу в свои руки?_Периодически  ...  \
# 0                                               True         ...
# 1                                              False         ...
# 2                                              False         ...
# 3                                              False         ...
# 4                                              False         ...
#
#    Формат работы_Посменно  Формат работы_Удаленка  Любите сладкое?_Нет  \
# 0                   False                   False                False
# 1                   False                    True                 True
# 2                   False                   False                 True
# 3                   False                   False                False
# 4                   False                    True                False
#
#    Любимое время года?_Зима  Любимое время года?_Лето  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                      True
# 4                     False                     False
#
#    Любимое время года?_Осень  Что пьют родители_Чай  \
# 0                      False                  False
# 1                      False                   True
# 2                      False                  False
# 3                      False                  False
# 4                       True                  False
#
#    Что пьют родители_Чай и кофе  Какие напитки любите_Холодные  Азартен?_Нет
# 0                          True                           True          True
# 1                         False                           True         False
# 2                         False                           True          True
# 3                          True                           True          True
# 4                          True                          False          True
#
# [5 rows x 41 columns]

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 41 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Возраст                                                   38 non-null     float64
#  1   Сколько спите ночью в среднем                             38 non-null     float64
#  2   Время подъема                                             38 non-null     float64
#  3   Ваш пол_Мужской                                           38 non-null     bool
#  4   Характер_Сангвиник                                        38 non-null     bool
#  5   Характер_Флегматик                                        38 non-null     bool
#  6   Характер_Холерик                                          38 non-null     bool
#  7   Что вы предпочитаете?_Чай                                 38 non-null     bool
#  8   Как часто вы берете инициативу в свои руки?_Очень часто   38 non-null     bool
#  9   Как часто вы берете инициативу в свои руки?_Периодически  38 non-null     bool
#  10  Как часто вы берете инициативу в свои руки?_Редко         38 non-null     bool
#  11  Как часто вы берете инициативу в свои руки?_Часто         38 non-null     bool
#  12  Как часто вы пропускаете завтраки?_Очень часто            38 non-null     bool
#  13  Как часто вы пропускаете завтраки?_Периодически           38 non-null     bool
#  14  Как часто вы пропускаете завтраки?_Редко                  38 non-null     bool
#  15  Как часто вы пропускаете завтраки?_Часто                  38 non-null     bool
#  16  Гипертония_Нет                                            38 non-null     bool
#  17  Курите?_Нет                                               38 non-null     bool
#  18  Пьете энергетики?_Нет                                     38 non-null     bool
#  19  Бывают ли проблемы со сном?_Нет                           38 non-null     bool
#  20  Повышенная тревожность?_Нет                               38 non-null     bool
#  21  Проблемы с концентрацией_Нет                              38 non-null     bool
#  22  Наличие кофейни возле дома_Нет                            38 non-null     bool
#  23  Какая культура ближе_Запад                                38 non-null     bool
#  24  Какая культура ближе_Не знаю                              38 non-null     bool
#  25  Любишь ли горькое_Нет                                     38 non-null     bool
#  26  Занимаетесь спортом?_Нет                                  38 non-null     bool
#  27  Выпиваете алкоголь_Нет                                    38 non-null     bool
#  28  Выпиваете алкоголь_Редко                                  38 non-null     bool
#  29  Формат работы_Не работаю                                  38 non-null     bool
#  30  Формат работы_Офис                                        38 non-null     bool
#  31  Формат работы_Посменно                                    38 non-null     bool
#  32  Формат работы_Удаленка                                    38 non-null     bool
#  33  Любите сладкое?_Нет                                       38 non-null     bool
#  34  Любимое время года?_Зима                                  38 non-null     bool
#  35  Любимое время года?_Лето                                  38 non-null     bool
#  36  Любимое время года?_Осень                                 38 non-null     bool
#  37  Что пьют родители_Чай                                     38 non-null     bool
#  38  Что пьют родители_Чай и кофе                              38 non-null     bool
#  39  Какие напитки любите_Холодные                             38 non-null     bool
#  40  Азартен?_Нет                                              38 non-null     bool
# dtypes: bool(38), float64(3)
# memory usage: 2.4 KB

# %%
X = data_encoded.drop('Что вы предпочитаете?_Чай', axis=1).values
Y = data_encoded['Что вы предпочитаете?_Чай'].values  # чай = True, кофе = False

# %%
X
# Out:
# array([[0.3333333333333333, 1.0, 0.8, ..., True, True, True],
#        [0.3333333333333333, 0.2, 0.2, ..., False, True, False],
#        [0.3333333333333333, 0.2, 0.3, ..., False, True, True],
#        ...,
#        [0.0, 0.6, 0.4, ..., False, True, True],
#        [0.0, 1.0, 0.7, ..., True, False, True],
#        [0.3333333333333333, 0.4, 0.3, ..., True, False, False]],
#       dtype=object)

# %%
Y
# Out:
# array([False,  True, False,  True,  True, False,  True,  True, False,
#        False,  True,  True, False, False, False,  True, False, False,
#         True,  True,  True,  True, False,  True,  True, False,  True,
#        False,  True,  True,  True,  True,  True, False, False,  True,
#        False,  True])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

# %%
import math
from collections import Counter


def euclidean_distance(point1, point2):
    distance = 0.0
    for i in range(len(point1)):
        distance += (point1[i] - point2[i]) ** 2
    return math.sqrt(distance)


def knn_predict_weighted(X_train, y_train, X_test, k):
    predictions = []
    for test_point in X_test:
        distances = []
        for i in range(len(X_train)):
            distance = euclidean_distance(X_train[i], test_point)
            distances.append((distance, y_train[i]))
        distances.sort(key=lambda x: x[0])


        weights = Counter()
        for distance, label in distances[:k]:
            weight = 1 / (distance + 1e-5)
            weights[label] += weight

        predictions.append(weights.most_common(1)[0][0])

    return predictions



def accuracy(y_true, y_pred):
    correct = sum(1 for true, pred in zip(y_true, y_pred) if true == pred)
    return correct / len(y_true)


best_k = 1
best_accuracy = 0
n = 40
for k in range(1, n + 1):
    predictions = knn_predict(X_train, y_train, X_test, k)
    acc = accuracy(y_test, predictions)
    print(f"Точность для k={k}: {acc:.2f}")

    if acc > best_accuracy:
        best_accuracy = acc
        best_k = k

print(f"Лучшее значение k: {best_k} с точностью {best_accuracy:.2f}")
# Out:
# Точность для k=1: 0.38
# Точность для k=2: 0.38
# Точность для k=3: 0.38
# Точность для k=4: 0.50
# Точность для k=5: 0.62
# Точность для k=6: 0.38
# Точность для k=7: 0.62
# Точность для k=8: 0.75
# Точность для k=9: 0.50
# Точность для k=10: 0.62
# Точность для k=11: 0.50
# Точность для k=12: 0.50
# Точность для k=13: 0.62
# Точность для k=14: 0.50
# Точность для k=15: 0.62
# Точность для k=16: 0.38
# Точность для k=17: 0.50
# Точность для k=18: 0.38
# Точность для k=19: 0.50
# Точность для k=20: 0.50
# Точность для k=21: 0.50
# Точность для k=22: 0.50
# Точность для k=23: 0.50
# Точность для k=24: 0.50
# Точность для k=25: 0.50
# Точность для k=26: 0.50
# Точность для k=27: 0.50
# Точность для k=28: 0.50
# Точность для k=29: 0.50
# Точность для k=30: 0.50
# Точность для k=31: 0.50
# Точность для k=32: 0.50
# Точность для k=33: 0.50
# Точность для k=34: 0.50
# Точность для k=35: 0.50
# Точность для k=36: 0.50
# Точность для k=37: 0.50
# Точность для k=38: 0.50
# Точность для k=39: 0.50
# Точность для k=40: 0.50
# Лучшее значение k: 8 с точностью 0.75
